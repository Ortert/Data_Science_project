# %% [markdown]
# ## Обучение с учителем: качество модели

# %% [markdown]
# **Описание и цель проекта:**
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
#
# Необходимо разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# **Описание данных:**
#
# ***Данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении — market_file.csv***
#
# *id* — номер покупателя в корпоративной базе данных.
#
# *Покупательская активность* — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
#
# *Тип сервиса* — уровень сервиса, например «премиум» и «стандарт».
#
# *Разрешить сообщать* — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
#
# *Маркет_актив_6_мес* — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
#
# *Маркет_актив_тек_мес* — количество маркетинговых коммуникаций в текущем месяце.
#
# *Длительность* — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
#
# *Акционные_покупки* — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
#
# *Популярная_категория* — самая популярная категория товаров у покупателя за последние 6 месяцев.
#
# *Средний_просмотр_категорий_за_визит* —  показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
#
# *Неоплаченные_продукты_штук_квартал* — общее число неоплаченных товаров в корзине за последние 3 месяца.
#
# *Ошибка_сервиса* — число сбоев, которые коснулись покупателя во время посещения сайта.
#
# *Страниц_за_визит* - среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
#
# ***Данные о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом — market_money.csv***
#
# *id* — номер покупателя в корпоративной базе данных.
#
# *Период* — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
#
# *Выручка* - сумма выручки за период.
#
#
# ***Данные о времени (в минутах), которое покупатель провёл на сайте в течение периода —  market_time.csv***
#
# *id* — номер покупателя в корпоративной базе данных.
#
# *Период* — название периода, во время которого зафиксировано общее время.
#
# *минут* — значение времени, проведённого на сайте, в минутах.
#
#
# ***Данные о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю —  money.csv***
#
# *id* — номер покупателя в корпоративной базе данных.
#
# *Прибыль* — значение прибыли.

# %% [markdown]
# **План работы:**
# 1.  [Загрузка данных:](#section_id)
# - загрузить данные. Файлы market_file.csv, market_money.csv, market_time.csv, money.csv доступны по ссылкам в описании данных или через пути к ним. Обратить внимание: в некоторых файлах разделитель значений — точка с запятой, а разделитель десятичных значений — запятая.
# - проверить, что данные в таблицах соответствуют описанию.
#
# 2. [Предобработка данных:](#section_id2)
# - провести необходимую предобработку данных. Названия столбцов можно оставить кириллическими.
#
# 3. [Исследовательский анализ данных](#section_id3)
# - провести исследовательский анализ данных из каждой таблицы.
# - отобрать клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период.
# - оформить выводы по результатам шага.
#
# 4. [Объединение таблиц](#section_id4)
# - объединить таблицы market_file.csv, market_money.csv, market_time.csv.
# - учесть, что данные о выручке и времени на сайте находятся в одном столбце для всех периодов. В итоговой таблице сделать отдельный столбец для каждого периода.
#
# 5. [Корреляционный анализ](#section_id5)
# - провести корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования.
# - сделать выводы о мультиколлинеарности и при необходимости устраните её.
#
# 6. [Использование пайплайнов](#section_id6)
#
# - во время подготовки данных использовать ColumnTransformer. Количественные и категориальные признаки обработать в пайплайне раздельно. Для кодирования категориальных признаков использовать как минимум два кодировщика, для масштабирования количественных — как минимум два скейлера.
# - обучить четыре модели: KNeighborsClassifier(), DecisionTreeClassifier(), LogisticRegression() и  SVC(). Для каждой из них подобрать как минимум один гиперпараметр. Выбрать подходящую для задачи метрику, аргументировать свой выбор. Используйте эту метрику при подборе гиперпараметров.
# - выбрать лучшую модель, используя заданную метрику. Для этого применить одну из стратегий:
#   использовать пайплайны и инструменты подбора гиперпараметров для каждой модели отдельно, чтобы выбрать лучшую модель самостоятельно;
#   использовать один общий пайплайн для всех моделей и инструмент подбора гиперпараметров, который вернёт вам лучшую модель.
#
#
# 7. [Анализ важности признаков](#section_id7)
#
# - оценить важность признаков для лучшей модели и построить график важности с помощью метода SHAP.
# - сделать выводы о значимости признаков:
#   какие признаки мало значимы для модели;
#   какие признаки сильнее всего влияют на целевой признак;
#   как можно использовать эти наблюдения при моделировании и принятии бизнес-решений.
#
# 8. [Сегментация покупателей](#section_id8)
#
# - выполнить сегментацию покупателей. Использовать результаты моделирования и данные о прибыльности покупателей.
# - выбрать группу покупателей и предложить, как увеличить её покупательскую активность:
#   Провести графическое и аналитическое исследование группы покупателей.
#   Сделать предложения по работе с сегментом для увеличения покупательской активности.
# - сделать выводы о сегментах:
#   какой сегмент вы взяли для дополнительного исследования,
#   какие предложения вы сделали и почему.
#
# 9. [Общий вывод](#section_id9)
#
#    Сделать общий вывод:
# - описать задачу;
# - описать исходные данные и проведённую предобработку;
# - описать, какие действия были выполнены для поиска лучшей модели;
# - указать лучшую модель;
# - добавить выводы и дополнительные предложения для выбранного сегмента покупателей.

# %% [markdown]
# Загружаем необходимые для выполнения исследований библиотеки:

# %%
import re
import pandas as pd
import numpy as np 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import (
    OneHotEncoder, OrdinalEncoder, LabelEncoder,
    StandardScaler, MinMaxScaler, RobustScaler
)
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
# !pip install shap
import shap

# %% [markdown]
# Создадим константу RANDOM_STATE для последующего использования в моделях обучения:

# %%
RANDOM_STATE = 42

# %% [markdown]
# Создадим константу TEST_SIZE для последующего использования в моделях обучения:

# %%
TEST_SIZE = 0.25

# %% [markdown]
# Настроим вывод всех строк и столбцов таблиц:

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Загрузка данных
# <a id='section_id'></a>

# %% [markdown]
# Загружаем датафрейм с информацией о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении:

# %%
try:
    
    market = pd.read_csv('/home/pc-mint/Загрузки/Pipline_project/market_file.csv')
except:
    
    market = pd.read_csv('/datasets/market_file.csv')

# %% [markdown]
# Выведем первые 5 строк, чтобы проверить корректность загрузки датафрейма и его соответствие описанию:

# %%
market.head()
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %% [markdown]
# Загружаем датафрейм с информацией о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом :

# %%
try:
    
    money = pd.read_csv('/home/pc-mint/Загрузки/Pipline_project/market_money.csv')
except:
    
    money = pd.read_csv('/datasets/market_money.csv')

# %% [markdown]
# Выведем первые 5 строк, чтобы проверить корректность загрузки датафрейма и его соответствие описанию:

# %%
money.head()
# Out:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6

# %% [markdown]
# Загружаем датафрейм с информацией о времени (в минутах), которое покупатель провёл на сайте в течение периода:

# %%
try:
    
    time = pd.read_csv('/home/pc-mint/Загрузки/Pipline_project/market_time.csv')
except:
    
    time = pd.read_csv('/datasets/market_time.csv')

# %% [markdown]
# Выведем первые 5 строк, чтобы проверить корректность загрузки датафрейма и его соответствие описанию:

# %%
time.head()
# Out:
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13

# %% [markdown]
# Загружаем датафрейм с информацией о среднемесячной прибыли покупателя за последние 3 месяца (какую прибыль получает магазин от продаж каждому покупателю):

# %%
try:
    
    profit = pd.read_csv('/home/pc-mint/Загрузки/Pipline_project/money.csv', sep=';', decimal=',')
except:
    
    profit = pd.read_csv('/datasets/money.csv')

# %% [markdown]
# Выведем первые 5 строк, чтобы проверить корректность загрузки датафрейма и его соответствие описанию:

# %%
profit.head()
# Out:
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %% [markdown]
# Для удобства дальнейшей работы, приведем наименование столбцов к единобразному виду (нижний регистр, нижнее подчеркивание между словами):

# %%
market.columns = [re.sub(r'( )', '_', i).lower() for i in market.columns]

# %% [markdown]
# Проверим что преобразование выполнено корректно:

# %%
market.columns
# Out:
# Index(['id', 'покупательская_активность', 'тип_сервиса', 'разрешить_сообщать',
#        'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность',
#        'акционные_покупки', 'популярная_категория',
#        'средний_просмотр_категорий_за_визит',
#        'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса',
#        'страниц_за_визит'],
#       dtype='object')

# %%
money.columns = [re.sub(r'( )', '_', i).lower() for i in money.columns]

# %%
money.columns
# Out:
# Index(['id', 'период', 'выручка'], dtype='object')

# %%
time.columns = [re.sub(r'( )', '_', i).lower() for i in time.columns]

# %%
time.columns
# Out:
# Index(['id', 'период', 'минут'], dtype='object')

# %%
profit.columns = [re.sub(r'( )', '_', i).lower() for i in profit.columns]

# %%
profit.columns
# Out:
# Index(['id', 'прибыль'], dtype='object')

# %% [markdown]
# Также исправим орфографические ошибки:
# - в датафрейме market, столбец 'тип_сервиса' значение "стандартт" заменим на "стандарт"
# - в датафрейме time, столбец 'период' значение "предыдцщий_месяц" заменим на "предыдущий_месяц"

# %%
market['тип_сервиса'] = market['тип_сервиса'].replace('стандартт', 'стандарт')

# %%
time['период'] = time['период'].replace('предыдцщий_месяц', 'предыдущий_месяц')

# %% [markdown]
# Проверим что замены прошли корректно:

# %%
market['тип_сервиса'].unique()
# Out:
# array(['премиум', 'стандарт'], dtype=object)

# %%
time['период'].unique()
# Out:
# array(['текущий_месяц', 'предыдущий_месяц'], dtype=object)

# %% [markdown]
# **Вывод:** датасеты необходимые для выполнения исследования загружены корректно, наполнение датасетов соответствует описанию. Наименования столбцов в датасетах приведены к единобразию (нижний регистр и нижние подчеркивания вместо пробелов), также устранены орфографические ошибки в наименованиях значений.
# <a id='section_id2'></a>

# %% [markdown]
# ##  Предобработка данных

# %% [markdown]
# Отфильтруем покупателей, у которых выручка за любой из последних трех месяцев была равна нулю:

# %%
money_zero = money.query('выручка == 0')

# %% [markdown]
# Создадим список id покупателей, у которых в какой-либо из последних трех месяцев, не было покупок:

# %%
zero_list = pd.Series(money_zero['id'].unique())

# %% [markdown]
# Исключим данных пользователей из датафреймов market, money, time, profit:

# %%
market = market[market['id'].isin(zero_list) == False]

# %%
money = money[money['id'].isin(zero_list) == False]

# %%
time = time[time['id'].isin(zero_list) == False]

# %%
profit = profit[profit['id'].isin(zero_list) == False]

# %% [markdown]
# Выведем общую информацию о датафреймах, проверим наличие пропусков в данных, а также корректность типов данных признаков:

# %%
market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1297 entries, 1 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1297 non-null   int64
#  1   покупательская_активность            1297 non-null   object
#  2   тип_сервиса                          1297 non-null   object
#  3   разрешить_сообщать                   1297 non-null   object
#  4   маркет_актив_6_мес                   1297 non-null   float64
#  5   маркет_актив_тек_мес                 1297 non-null   int64
#  6   длительность                         1297 non-null   int64
#  7   акционные_покупки                    1297 non-null   float64
#  8   популярная_категория                 1297 non-null   object
#  9   средний_просмотр_категорий_за_визит  1297 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1297 non-null   int64
# ...

# %%
money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3891 entries, 3 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3891 non-null   int64
#  1   период   3891 non-null   object
#  2   выручка  3891 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 121.6+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2594 entries, 2 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2594 non-null   int64
#  1   период  2594 non-null   object
#  2   минут   2594 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 81.1+ KB

# %%
profit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1297 entries, 1 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1297 non-null   int64
#  1   прибыль  1297 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 30.4 KB

# %% [markdown]
# Как видно из таблиц выше, пропуски в исследуемых датасетах отсутствуют, типы данных значений корректные, в преобразовании не нуждаются

# %% [markdown]
# Проверим датасеты на наличие явных дубликатов:

# %%
market.duplicated().sum()
# Out:
# 0

# %%
money.duplicated().sum()
# Out:
# 0

# %%
time.duplicated().sum()
# Out:
# 0

# %%
profit.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явные дубликаты в датасете отсутствуют

# %% [markdown]
# Проверим данные на наличие неявных дубликатов - нет ли в датасетах задублированных id:

# %%
market.duplicated('id').sum()
# Out:
# 0

# %%
money.duplicated('id').sum()
# Out:
# 2594

# %%
time.duplicated('id').sum()
# Out:
# 1297

# %%
profit.duplicated('id').sum()
# Out:
# 0

# %% [markdown]
# Неявные дубликаты также отсутствуют в датасетах. 2594 дубликатов датафрейма money и 1297 дубликатов датафрейма time, обусловлены тем, что данные для 1297 пользователей выводятся для 3-х периодов в первом случае и для двух периодов - во втором

# %% [markdown]
# **Вывод:**  Датасеты проверены на наличие пропусков, корректность типа данных, явных и неявных дубликатов (по номеру id). Пропуски и дубликаты в исследуемых датафреймах не выявлены, типы данных значений корректны. Дополнительная обработка данных не требуется.<a id='section_id3'></a>

# %% [markdown]
# ##  Исследовательский анализ данных

# %% [markdown]
# Выведем основные статистические показатели для каждого датасета:

# %%
market.describe().T
# Out:
#                                       count           mean         std  \
# id                                   1297.0  215998.986893  374.578554
# маркет_актив_6_мес                   1297.0       4.254433    1.015618
# маркет_актив_тек_мес                 1297.0       4.009252    0.696048
# длительность                         1297.0     602.993832  249.101456
# акционные_покупки                    1297.0       0.320547    0.249657
# средний_просмотр_категорий_за_визит  1297.0       3.267540    1.354623
# неоплаченные_продукты_штук_квартал   1297.0       2.841172    1.973451
# ошибка_сервиса                       1297.0       4.184271    1.950973
# страниц_за_визит                     1297.0       8.186584    3.977061
#
#                                            min        25%        50%  \
# id                                   215349.00  215675.00  215999.00
# маркет_актив_6_мес                        0.90       3.70       4.20
# ...

# %%
money.describe()
# Out:
#                   id        выручка
# count    3891.000000    3891.000000
# mean   215998.986893    5033.718890
# std       374.482249    1768.471286
# min    215349.000000    2758.700000
# 25%    215675.000000    4592.000000
# 50%    215999.000000    4959.000000
# 75%    216323.000000    5363.200000
# max    216647.000000  106862.200000

# %%
time.describe()
# Out:
#                   id        минут
# count    2594.000000  2594.000000
# mean   215998.986893    13.340401
# std       374.506318     4.081999
# min    215349.000000     4.000000
# 25%    215675.000000    10.000000
# 50%    215999.000000    13.000000
# 75%    216323.000000    16.000000
# max    216647.000000    23.000000

# %%
profit.describe()
# Out:
#                   id      прибыль
# count    1297.000000  1297.000000
# mean   215998.986893     3.997610
# std       374.578554     1.010813
# min    215349.000000     0.860000
# 25%    215675.000000     3.300000
# 50%    215999.000000     4.040000
# 75%    216323.000000     4.670000
# max    216647.000000     7.430000

# %% [markdown]
# Исходя из статистик, представленных в таблицах выше, в данных не наблюдается аномальных значений. Рассмотрим распределение величин параметров на графиках:

# %% [markdown]
# Напишем функции для вывода основных статистических парметров (метод .describe()) и графиков количественных и категориальных параметров

# %% [markdown]
# Для количественных параметров будем строить гистограмму и "ящик с усами":

# %%
def num_stat_and_graph(df, col, n, title):
    stat = df[col].describe()
    fig, axes = plt.subplots(1,2, figsize=(15,5))
    sns.histplot(df[col], kde=True, bins=n, ax=axes[0])
    sns.boxplot(data=df, x=col)
    fig.suptitle(title);
    return stat

# %% [markdown]
# Для категориальных параметров будем строить круговую диаграмму:

# %%
def cat_graph(df, col, title):
    fig,axes = plt.subplots(figsize=(7,7))
    labels = df[col].unique()
    explode = []
    for i in labels:
        explode.append(0.02)
        
    plt.pie(df[col].value_counts(), labels=labels, explode=explode, startangle=90, autopct='%1.0f%%')    
    plt.title(title);

# %% [markdown]
# Рассмотрим распределение прарметров датафрейма market:

# %%
cat_graph(
    market, 'покупательская_активность', 
    'Распределение классов покупательской активности (целевой признак): «снизилась» или «прежний уровень» '
)

# %% [markdown]
# Как видно из диаграммы выше, покупательская активность снизилась для 62% клиентов онлайн-магазина

# %%
cat_graph(
    market, 'тип_сервиса', 
    'Распределение категорий уровня сервиса, например «премиум» и «стандарт»'
)

# %% [markdown]
# Как видно из диаграммы выше, большая часть покупателей (72%) имеют категорию сервиса "премиум"

# %%
cat_graph(
    market, 'разрешить_сообщать', 
    'Распределение пользователей которые дали/не дали согласие на направление им маркетинговых предложений'
)

# %% [markdown]
# Как видно из диаграммы выше, большая часть покупателей (74%) дали согласие на направление им маркетинговой информации

# %%
num_stat_and_graph(
    market, 'маркет_актив_6_мес', 50, 
    'Распределение среднемесячного значения маркетинговых коммуникаций за последние 6 мес., шт.'
)
# Out:
# count    1297.000000
# mean        4.254433
# std         1.015618
# min         0.900000
# 25%         3.700000
# 50%         4.200000
# 75%         4.900000
# max         6.600000
# Name: маркет_актив_6_мес, dtype: float64

# %% [markdown]
# Несмотря на тот факт, что график boxplot считает значения среднемесячных маркетинговых коммуникаций (0.9, 1.4, 1.5, 1.7) выбросами, нет оснований считать их таковыми, т.к. они укладываются в диапазон возможных значений данного параметра. Также заметно что распределение параметра 'маркет_актив_6_мес' тяготеет к нормальному распределению с пиком частоты в районе значения 4.4.

# %%
num_stat_and_graph(
    market, 'маркет_актив_тек_мес', 50, 
    'Распределение количества маркетинговых коммуникаций в текущем месяце, шт.'
)
# Out:
# count    1297.000000
# mean        4.009252
# std         0.696048
# min         3.000000
# 25%         4.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: маркет_актив_тек_мес, dtype: float64

# %% [markdown]
# Значения параметров в данном столбце распределены между величинами 3, 4 и 5. Выбросов и аномальных значений в распределении не наблюдается.

# %%
num_stat_and_graph(
    market, 'длительность', 50, 
    'Распределение времени с момента регистрации покупателя на сайте., дней.'
)
# Out:
# count    1297.000000
# mean      602.993832
# std       249.101456
# min       121.000000
# 25%       410.000000
# 50%       607.000000
# 75%       806.000000
# max      1079.000000
# Name: длительность, dtype: float64

# %% [markdown]
# Распределение на графиках выше имеет вид нормально распределенного, с небольшим смещением влево. Аномальных значений и выбросов не выявлено

# %%
num_stat_and_graph(
    market, 'акционные_покупки', 50, 
    'Распределение среднемесячной доли покупок по акции, от общего числа покупок за последние 6 мес.'
)
# Out:
# count    1297.000000
# mean        0.320547
# std         0.249657
# min         0.110000
# 25%         0.170000
# 50%         0.240000
# 75%         0.300000
# max         0.990000
# Name: акционные_покупки, dtype: float64

# %% [markdown]
# Как видно из графиков выше, среднемесячное значение доли покупок по акции, колеблется в диапазоне 0-0.45 для большей части пользователей, однако также отчетливо выделяется группа пользователей с долей акционных покупок в диапазоне 0.85-1.0.

# %%
market.sample(10)
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 911   216259           Прежний уровень     премиум                 да
# 1212  216560           Прежний уровень    стандарт                нет
# 1223  216571           Прежний уровень    стандарт                нет
# 932   216280           Прежний уровень    стандарт                 да
# 763   216111           Прежний уровень    стандарт                 да
# 467   215815                 Снизилась    стандарт                 да
# 812   216160           Прежний уровень    стандарт                 да
# 8     215356                 Снизилась    стандарт                 да
# 307   215655                 Снизилась    стандарт                 да
# 323   215671                 Снизилась     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 911                  4.7                     5           150
# 1212                 4.4                     4           891
# ...

# %%
cat_graph(
    market, 'популярная_категория', 
    'Распределение самых популярных категорий товаров'
)

# %% [markdown]
# Как видно из диаграммы выше, наиболее популярной категорией товаров среди покупателей онлайн-магазина, являются "Товары для детей" (25%), наименее популярная категория - "Мелкая бытовая техника и электроника" (11%)

# %%
num_stat_and_graph(
    market, 'средний_просмотр_категорий_за_визит', 50, 
    'Распределение среднего количества категорий, просмотренных покупателем в течение последнего месяца, шт.'
)
# Out:
# count    1297.000000
# mean        3.267540
# std         1.354623
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         6.000000
# Name: средний_просмотр_категорий_за_визит, dtype: float64

# %% [markdown]
# Значения параметров в данном столбце распределены в диапазоне (1-6), распредеоение имеет вид нормального, со смещением влево, вершина распределения - значение 3.0. Выбросов и аномальных значений в распределении не наблюдается.

# %%
num_stat_and_graph(
    market, 'неоплаченные_продукты_штук_квартал', 50, 
    'Распределение общего числа неоплаченных товаров в корзине за последние 3 месяца, шт.'
)
# Out:
# count    1297.000000
# mean        2.841172
# std         1.973451
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: неоплаченные_продукты_штук_квартал, dtype: float64

# %% [markdown]
# Основная масса значений параметра в данном столбце распределена в диапазоне (0-5). Несмотря на то, что "ящик с усами" считает значения 9 и 10 выбросами, нет оснований считать их таковыми.

# %%
num_stat_and_graph(
    market, 'ошибка_сервиса', 50, 
    'Распределение числа сбоев, которые коснулись покупателя во время посещения сайта, шт.'
)
# Out:
# count    1297.000000
# mean        4.184271
# std         1.950973
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         6.000000
# max         9.000000
# Name: ошибка_сервиса, dtype: float64

# %% [markdown]
# Распределение на графиках выше имеет вид нормально распределенного, с небольшим смещением влево, вершиной является значение - 4.0. Аномальных значений и выбросов не выявлено

# %%
num_stat_and_graph(
    market, 'страниц_за_визит', 50, 
    'Распределение среднего кол-ва страниц, просмотренных покупателем за 1 визит на сайт за последние 3 мес., шт.'
)
# Out:
# count    1297.000000
# mean        8.186584
# std         3.977061
# min         1.000000
# 25%         5.000000
# 50%         8.000000
# 75%        11.000000
# max        20.000000
# Name: страниц_за_визит, dtype: float64

# %% [markdown]
# Распределение на графиках выше имеет вид нормально распределенного, с выраженным смещением влево, вершиной является значение - 5.0. Аномальных значений и выбросов не выявлено

# %% [markdown]
# Рассмотрим распределение прарметров датафрейма money:

# %%
cat_graph(
    money, 'период', 
    'Распределение периодов, во время которого зафиксирована выручка'
)

# %% [markdown]
# Как видно из диаграммы выше, фиксация выручки выаполнялась для всех имеющихся клиентов, в течение трех последних месяцев

# %%
num_stat_and_graph(
    money, 'выручка', 50, 
    'Распределение суммы выручки за период'
)
# Out:
# count      3891.000000
# mean       5033.718890
# std        1768.471286
# min        2758.700000
# 25%        4592.000000
# 50%        4959.000000
# 75%        5363.200000
# max      106862.200000
# Name: выручка, dtype: float64

# %% [markdown]
# Как видно из графиков выше, распределение параметра 'выручка' имеет выброс значением 106862. Рассмотрим подробнее диапазон значений 0 - 20000, без учета данного выброса

# %%
fig, axes = plt.subplots(1,2, figsize=(15,5))
sns.histplot(money['выручка'], bins=250, kde=True, ax = axes[0])
axes[0].set_xlim(0,12000)
sns.boxplot(data=money, x= 'выручка')
axes[1].set_xlim(0,12000)
fig.suptitle('Распределение суммы выручки за период');

# %% [markdown]
# В данном диапазоне распредленеие выручки имеет вид нормального. Для значений, лежищих за пределами "усов" "ящика", нет оснований считать их выбросами.

# %% [markdown]
# Рассмотрим подробнее диапазон значений 105000 - 107000 - значения, в районе обнаруженного выброса:

# %%
fig, axes = plt.subplots(figsize=(15,5))
sns.histplot(money['выручка'],  bins=500)
axes.set_xlim(100000, 110000)
axes.set_ylim(0, 5);

# %% [markdown]
# Как видно из графика выше, значение 106862, является единственным значением, сильно выбивающимся из общего набора данных. Однако считать его аномальным и удалять данное значение из датасета оснований не имеется (если была бы такая возможность, стоило бы уточнить у смежных подразделений реальность данной позиции), т.к. данная цифра вполне реальна.

# %% [markdown]
# Рассмотрим распределение прарметров датафрейма time:

# %%
cat_graph(
    time, 'период', 
    'Распределение периодов, во время которого зафиксировано общее время.'
)

# %% [markdown]
# Как видно из диаграммы выше, фиксация общего времени выаполнялась для всех имеющихся клиентов, в течение двух последних месяцев

# %%
num_stat_and_graph(
    time, 'минут', 50, 
    'Распределение значение времени, проведённого на сайте, минуты'
)
# Out:
# count    2594.000000
# mean       13.340401
# std         4.081999
# min         4.000000
# 25%        10.000000
# 50%        13.000000
# 75%        16.000000
# max        23.000000
# Name: минут, dtype: float64

# %% [markdown]
# Распределение на графиках выше имеет вид нормально распределенного, с заметным смещением влево, вершиной является значение - 14.0. Аномальных значений и выбросов не выявлено

# %% [markdown]
# Рассмотрим распределение прарметров датафрейма profit:

# %%
num_stat_and_graph(
    profit, 'прибыль', 50, 
    'Распределение значений прибыли'
)
# Out:
# count    1297.000000
# mean        3.997610
# std         1.010813
# min         0.860000
# 25%         3.300000
# 50%         4.040000
# 75%         4.670000
# max         7.430000
# Name: прибыль, dtype: float64

# %% [markdown]
# Распределение на графиках выше имеет вид нормально распределенного, с небольшим смещением влево, четко выраженной вершины не наблюдается. Аномальных значений и выбросов не выявлено

# %% [markdown]
# **Вывод:** Из всех датасетов удалены id пользователей, имеющих выручку равную нулю, хотя бы в одном, из трех последних месяцев. По результатам проведенного исследовательского анализа изучаемых датасетов, можно прийти к выводу, что вцелом представленные данные не содержат аномальных значений. Столбец 'выручка' датасета money имеет выброс значением 106862, однако данное значение реально в рамках имеющегося набора данных и поэтому датафрейм money оставлен без изменений. Распределение значений вцелом имеет вид нормального с более или менее выраженными смещениями относительно центра значений. Анализ покупательской способности показал, что каждый из клиентов, совершал покупки как минимум в одном из трех последних месяцев.
# <a id='section_id4'></a>

# %% [markdown]
# ## Объединение таблиц

# %% [markdown]
# Выполним объединение датасетов market, money и time в один датафрем - df:

# %% [markdown]
# Сначала преобразуем таблицы money и time: значения выручки и времени для каждого периода, пропишем в отдельном столбце:

# %%
money_split = money.copy()

# %%
money_split['выручка_препредыдущий_месяц'] = (
    money_split
    .query('период == "препредыдущий_месяц"')['выручка']
)

# %%
money_split['выручка_препредыдущий_месяц'] = money_split['выручка_препредыдущий_месяц'].fillna(0)

# %%
money_split['выручка_предыдущий_месяц'] = (
    money_split
    .query('период == "предыдущий_месяц"')['выручка']
)

# %%
money_split['выручка_предыдущий_месяц'] = money_split['выручка_предыдущий_месяц'].fillna(0)

# %%
money_split['выручка_текущий_месяц'] = (
    money_split
    .query('период == "текущий_месяц"')['выручка']
)

# %%
money_split['выручка_текущий_месяц'] = money_split['выручка_текущий_месяц'].fillna(0)

# %%
money_split = money_split.drop(['выручка', 'период'], axis=1)

# %% [markdown]
# Проверим что новые столбцы созданы корректно:

# %%
money_split.head()
# Out:
#        id  выручка_препредыдущий_месяц  выручка_предыдущий_месяц  \
# 3  215349                       4472.0                       0.0
# 4  215349                          0.0                       0.0
# 5  215349                          0.0                    5216.0
# 6  215350                       4826.0                       0.0
# 7  215350                          0.0                       0.0
#
#    выручка_текущий_месяц
# 3                    0.0
# 4                 4971.6
# 5                    0.0
# 6                    0.0
# 7                 5058.4

# %%
time_split = time.copy()

# %%
time_split['минут_предыдущий_месяц'] = (
    time_split
    .query('период == "предыдущий_месяц"')['минут']
)

# %%
time_split['минут_предыдущий_месяц'] = time_split['минут_предыдущий_месяц'].fillna(0)

# %%
time_split['минут_текущий_месяц'] = (
    time_split
    .query('период == "текущий_месяц"')['минут']
)

# %%
time_split['минут_текущий_месяц'] = time_split['минут_текущий_месяц'].fillna(0)

# %%
time_split = time_split.drop(['минут', 'период'], axis=1)

# %% [markdown]
# Проверим что новые столбцы созданы корректно:

# %%
time_split.head()
# Out:
#        id  минут_предыдущий_месяц  минут_текущий_месяц
# 2  215349                     0.0                 10.0
# 3  215349                    12.0                  0.0
# 4  215350                     0.0                 13.0
# 5  215350                     8.0                  0.0
# 6  215351                     0.0                 13.0

# %% [markdown]
# Выполним объединение таблиц market и money_split:

# %%
df = market.merge(money_split, on='id')

# %% [markdown]
# Проверим что объединение выполнено корректно:

# %%
df.head()
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215349                 Снизилась     премиум                 да
# 3  215350                 Снизилась    стандарт                нет
# 4  215350                 Снизилась    стандарт                нет
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.4                     4           819               0.75
# 2                 4.4                     4           819               0.75
# 3                 4.9                     3           539               0.14
# 4                 4.9                     3           539               0.14
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# ...

# %% [markdown]
# Полученный объединенный датафрейм объединим с таблицей time_split:

# %%
df=df.merge(time_split, on='id')

# %% [markdown]
# Проверим что объединение выполнено корректно:

# %%
df.head()
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215349                 Снизилась     премиум                 да
# 3  215349                 Снизилась     премиум                 да
# 4  215349                 Снизилась     премиум                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.4                     4           819               0.75
# 2                 4.4                     4           819               0.75
# 3                 4.4                     4           819               0.75
# 4                 4.4                     4           819               0.75
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# ...

# %% [markdown]
# **Вывод:** выполнено объединение датасетов market, money и time в один датафрейм. Значения выручки и времени из датасетов money и time,  пропиcаны в отдельном столбце для каждого периода.
# <a id='section_id5'></a>

# %% [markdown]
# ## Корелляционный анализ

# %% [markdown]
# Как было определено в разделе исследовательский анализ, не все распределения исследуемых параметров соответствуют нормальному распределению. На основании этого определим коэффициенты корреляции Спирмена, составим корреляционную матрицу и выведем тепловую карту со значениями коэффициентов:

# %% [markdown]
# Также выведем коэффициенты корреляции Спирмена:

# %%
corr_spearman = df.corr(method='spearman', numeric_only=True)

# %%
corr_spearman
# Out:
#                                            id  маркет_актив_6_мес  \
# id                                   1.000000            0.341026
# маркет_актив_6_мес                   0.341026            1.000000
# маркет_актив_тек_мес                -0.006258            0.061697
# длительность                        -0.061987           -0.044614
# акционные_покупки                   -0.379846           -0.277968
# средний_просмотр_категорий_за_визит  0.280582            0.185027
# неоплаченные_продукты_штук_квартал  -0.257080           -0.134368
# ошибка_сервиса                       0.099014            0.038656
# страниц_за_визит                     0.527716            0.319918
# выручка_препредыдущий_месяц          0.045178            0.030905
# выручка_предыдущий_месяц            -0.010479           -0.000749
# выручка_текущий_месяц               -0.012897           -0.000017
# минут_предыдущий_месяц               0.129831            0.073066
# ...

# %%
ax, fig = plt.subplots(figsize=(10,10))
sns.heatmap(corr_spearman, annot=corr_spearman, cmap='coolwarm', fmt='.2f',  annot_kws={"size":10});

# %% [markdown]
# Как видно по коэффициентам корреляции в матрице и тепловой карте выше, в исследуемом датасете отсутствуют сильнокоррелирующие положительно параметры, имеются параметры имеющие сильную отрицательную корреляцию - 'минут_предыдущий_месяц' и 'минут_текущий_месяц'. Учтем данный факт при дальнейшем моделировании.

# %% [markdown]
# **Вывод:** Определены коэффициенты корреляции Спирмена, построены матрица и тепловыая карта со значениями коэффициентов корреляции. Сильнокоррелирующие положительно параметры не выявлены, имеются параметры имеющие сильную отрицательную корреляцию - 'минут_предыдущий_месяц' и 'минут_текущий_месяц'.
# <a id='section_id6'></a>

# %% [markdown]
# ## Использование пайплайнов

# %% [markdown]
# Напишем пайплайн для определения лучших кодировщиков, скейлеров и моделей машинного обучения.
# В качестве кодировщиков примем кодировщики OheHotEncoder и OrdinalEncoder.
# В качестве скейлеров используем StandaradScaler, MinMaxScaler, RobustScaler.
# В качестве моделей МО применим KNeighborsClassifier() (перебираем гиперпараметр 'n_neighbors', DecisionTreeClassifier() (перебираем гиперпараметры 'max_depth', 'min_samples_split', 'min_samples_leaf' , LogisticRegression(перебираем гиперпараметр 'С') и SVC(перебираем гиперпараметр 'degree').
# В качестве метрики, с помощью которой будет оцениваться качество модели, будем использовать ROC-AUC, т.к. она показывает отношение верно классифицированных объектов класса 1 (клиенты, по которым прогнозируется снижение покупательской активности) к ошибочно классифицированным объектам (когда покупателя для которого покупательная способность не снизилась бы, мы классифицировали как целевого клиента), на всех порогах классификациию Таким образом мы максимизируем выявление клиентов, чья покупателсьская способность снизится, что и является целью данного исследования.

# %%
X = df.drop(['id', 'покупательская_активность'], axis=1)
y = df['покупательская_активность']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
    stratify=y
)

cat_columns = ['тип_сервиса', 'разрешить_сообщать', 'популярная_категория']
num_columns = [
    'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность', 'акционные_покупки', ''
    'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 
    'страниц_за_визит', 'выручка_препредыдущий_месяц', 'выручка_предыдущий_месяц', 'выручка_текущий_месяц', 
    'минут_предыдущий_месяц', 'минут_текущий_месяц']

ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]
)

ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord', OrdinalEncoder(
               categories=[
                   ['стандарт', 'премиум'],
                   ['нет', 'да'],
                   ['Мелкая бытовая техника и электроника', 'Кухонная посуда', 'Техника для красоты и здоровья',
                       'Косметика и аксесуары', 'Домашний текстиль', 'Товары для детей']
               ],
               handle_unknown = 'use_encoded_value', unknown_value=np.nan
          )
       ),
     ('simpleImputer_sfter_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)


data_preprocessor = ColumnTransformer(
    [('cat', ord_pipe, cat_columns),
    ('num', StandardScaler(), num_columns)
    ],
    remainder='passthrough'
)

pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', LogisticRegression(random_state=RANDOM_STATE))
])

param_grid = [
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE,
            solver='liblinear',
            penalty='l1'
        )],
        'models__C': range(1,3),
        'preprocessor__cat': [ohe_pipe, ord_pipe, 'passthrough'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    },

    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(1,20),
        'preprocessor__cat': [ohe_pipe, ord_pipe, 'passthrough'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    
    {
        'models': [DecisionTreeClassifier(
            random_state=RANDOM_STATE
        )],
        'models__max_depth': range(1,30),
        'models__min_samples_split': range(2,10),
        'models__min_samples_leaf': range(1,10),
        'preprocessor__cat': [ohe_pipe, ord_pipe, 'passthrough'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    }
]

grid_search = GridSearchCV(
    pipe_final,
    param_grid,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1
)

label_encoder = LabelEncoder()

y_train = label_encoder.fit_transform(y_train)

y_test = label_encoder.transform(y_test)

grid_search.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', grid_search.best_estimator_)
print('Лучшая метрика на кросс-валидационной выборке:', grid_search.best_score_)


y_test_pred = grid_search.predict(X_test)
probas = grid_search.predict_proba(X_test)

print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, probas[:,1])}')
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['тип_сервиса',
#                                                    'разрешить_сообщать',
# ...

# %% [markdown]
# **Вывод:** Для поиска лучшей модели и метрики для поиска клиентов покупательская активность которых будет снижаться в ближайшее время, построен и просчитан пайплайн, со следующими исходными параметрами:
#
# - в качестве кодировщиков использовались OheHotEncoder и OrdinalEncoder.
# - в качестве скейлеров использовались StandaradScaler, MinMaxScaler, RobustScaler.
# - в качестве моделей МО применялись KNeighborsClassifier() (перебирали гиперпараметр 'n_neighbors', DecisionTreeClassifier() (перебирали гиперпараметры 'max_depth', 'min_samples_split', 'min_samples_leaf' , LogisticRegression(перебирали гиперпараметр 'С') и SVC(перебирали гиперпараметр 'degree').
# - в качестве метрики, с помощью которой будет оценивалось качество модели, использовали ROC-AUC.
#
# По итогу лучшие показатели показала модель со следующими параметрами:
# - кодировщик OheHotEncoder;
# - скейлер StandaradScaler;
# - модель DecisionTreeClassifier() с гиперпараметрами 'max_depth' = 18, 'min_samples_split' = 8.
#
# Лучшая метрика ROC-AUC полученная на кросс-валидационной выборке равно 0.9874060771432089
#
# Лучшая метрика ROC-AUC полученная на тестовой выборке равно 0.9961815962561071
#
# Исходя из полученных значений разброса и смещенияможно сказать о том, что модель получила достаточно сведений для принятия решений, при этом не переобучившись.
# <a id='section_id7'></a>

# %% [markdown]
# ## Анализ важности признаков

# %% [markdown]
# Оценим важность признаков, для модели с наилучшими значениями метрик, полученной в разделе выше и построим график важности с помощью метода SHAP:

# %% [markdown]
# Построим диаграмму shap.plots.beeswarm и диаграмму shap.plots.bar:

# %% [markdown]
# Применим лучшую модель, полученную по итогам работы пайплайна:

# %%
model = grid_search.best_estimator_

# %%
model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['тип_сервиса',
#                                                    'разрешить_сообщать',
#                                                    'популярная_категория']),
# ...

# %% [markdown]
# Обучим и преобразуем массив X_train:

# %%
model['preprocessor'].fit(X_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('cat',
#                                  Pipeline(steps=[('simpleImputer_ohe',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['тип_сервиса', 'разрешить_сообщать',
#                                   'популярная_категория']),
#                                 ('num', StandardScaler(),
#                                  ['маркет_актив_6_мес', 'маркет_актив_тек_мес',
#                                   'длительность', 'акционные_покупки',
#                                   'средний_просмотр_категорий_за_визит',
# ...

# %%
X_train_preprocessed = model['preprocessor'].transform(X_train)

# %% [markdown]
# Выделим имена столбцов массива X_train, полученный после преобразования кодировщиком и скейлером:

# %%
column_names = model['preprocessor'].get_feature_names_out()

# %%
column_names
# Out:
# array(['cat__тип_сервиса_стандарт', 'cat__разрешить_сообщать_нет',
#        'cat__популярная_категория_Косметика и аксесуары',
#        'cat__популярная_категория_Кухонная посуда',
#        'cat__популярная_категория_Мелкая бытовая техника и электроника',
#        'cat__популярная_категория_Техника для красоты и здоровья',
#        'cat__популярная_категория_Товары для детей',
#        'num__маркет_актив_6_мес', 'num__маркет_актив_тек_мес',
#        'num__длительность', 'num__акционные_покупки',
#        'num__средний_просмотр_категорий_за_визит',
#        'num__неоплаченные_продукты_штук_квартал', 'num__ошибка_сервиса',
#        'num__страниц_за_визит', 'num__выручка_препредыдущий_месяц',
#        'num__выручка_предыдущий_месяц', 'num__выручка_текущий_месяц',
#        'num__минут_предыдущий_месяц', 'num__минут_текущий_месяц'],
#       dtype=object)

# %%
data = pd.DataFrame(X_train_preprocessed, columns=column_names)

# %%
explainer = shap.TreeExplainer(model['models'], data=data)
shap_values = explainer(data)

# %%
shap.summary_plot(shap_values[:,:,1], data,  plot_type='bar', plot_size = (11,7))

# %%
shap.plots.beeswarm(shap_values[:,:,1], max_display=20)

# %% [markdown]
# **Вывод:** По результатам анализа полученных графиков, можно прийти к следующим выводам:
# Возьмем за границу, разделяющую важные признаки от неважных - среднее значение Шепли, равные 0.02.
# Тогда получим, что:
# - менее всего на прогноз целевого признака влияют следующие входные параметры: 'выручка', 'тип_сервиса', 'разрешить_сообщать', 'маркет_актив_тек_месяц';
# - более всего на прогноз целевого признака влияют следующие входные параметры: 'страниц за визит', 'акционные_покупки', 'маркет_актив_6_мес', 'просмотр категорий за визит', 'минут', 'неоплаченные_продукты_штук_квартал', 'длительность', 'ошибка_сервиса'.
#
# На основании описанного выше, для увеличения покупательской активности вцелом можно рекомендовать отделу маркетинга делать рассылки, которые приводят к переходу покупателей на страницы магазина, т.к. 'страниц за визит' это самый влиятельный входной признак (также в числе влиятельный признаков 'просмотр категорий за визит', 'минут', 'длительность' - величина данных параметров зависит от количетсва переходов и степенью заинтересованности информацией на страницах сайта/приложения. Также можно рекомендовать предложение клиентам акционных покупок и увеличение маркетинговой активности целом.
# <a id='section_id8'></a>

# %% [markdown]
# ## Сегментация покупателей

# %% [markdown]
# Выберем сегмент покупателей, для которых будет предлагаться проведение маркетингового актива, с целью повышения покупательской активности

# %% [markdown]
# Для этого:
# - создадим новый датафрейм, содержащий прогнозы о снижении покупательской активности;
# - объединим полученный датафрейм с id покупателей, для которых сделан прогноз
# - удаляем задублированные строки
# - отфильтруем из полученного датафрейма, строки с прогнозными значениями равными "1" (снижение покупательской активности)
# - объединим полученный датафрейм со столбцом 'прибыль' из датафрейма profit
# - отфильтруем полученных клиентов по убыванию прибыли

# %%
predict = pd.Series(grid_search.predict(X))

# %%
probas
# Out:
# array([[0., 1.],
#        [1., 0.],
#        [1., 0.],
#        ...,
#        [1., 0.],
#        [0., 1.],
#        [1., 0.]])

# %%
predict_df = (
    pd
    .concat([predict, df['id']], axis=1)
    .drop_duplicates()
    .reset_index(drop=True)
)

# %%
predict_df.columns = ['predict', 'id']

# %%
predict_df = predict_df.query('predict == 1')

# %%
most_profit_clients = (
    predict_df
    .merge(profit, on='id', how='left')
    .sort_values('прибыль', ascending=False)
)

# %% [markdown]
# Добавим к полученному датафрейму столбец с информацией о популярной категории товаров у отфильтрованных покупателей:

# %%
most_profit_clients = most_profit_clients.merge(market[['id', 'популярная_категория']], on='id')

# %% [markdown]
# Определим наиболее популярные категории товаров, среди отфильрованных покупателей:

# %%
most_profit_clients['популярная_категория'].value_counts()
# Out:
# популярная_категория
# Товары для детей                        147
# Косметика и аксесуары                   105
# Домашний текстиль                       101
# Кухонная посуда                          67
# Техника для красоты и здоровья           50
# Мелкая бытовая техника и электроника     28
# Name: count, dtype: int64

# %% [markdown]
# Отфильтруем пользователей, совершающих покупки в топ-3 категориях по популярности и посмотрим сколько пользователей окажется в этом списке:

# %%
filter_list = ['Товары для детей', 'Домашний текстиль', 'Косметика и аксесуары']
most_profit_clients = most_profit_clients[most_profit_clients['популярная_категория'].isin(filter_list)]

# %%
most_profit_clients
# Out:
#      predict      id  прибыль   популярная_категория
# 0          1  215401     7.43  Косметика и аксесуары
# 1          1  215563     6.88  Косметика и аксесуары
# 2          1  215400     6.73       Товары для детей
# 3          1  215561     6.59  Косметика и аксесуары
# 4          1  215505     6.55       Товары для детей
# 5          1  215439     6.33       Товары для детей
# 7          1  215897     6.24       Товары для детей
# 8          1  215494     6.12  Косметика и аксесуары
# 9          1  215820     6.09       Товары для детей
# 12         1  215456     5.83  Косметика и аксесуары
# 13         1  215555     5.79       Товары для детей
# 14         1  215639     5.74       Товары для детей
# 15         1  215649     5.71       Товары для детей
# 16         1  215390     5.70  Косметика и аксесуары
# 17         1  215684     5.70       Товары для детей
# 18         1  215690     5.66  Косметика и аксесуары
# 22         1  215484     5.64       Товары для детей
# ...

# %%
most_profit_clients.shape[0]
# Out:
# 353

# %% [markdown]
# Посмотрим на распределение прибыли в отфильтрованном датафрейме:

# %%
num_stat_and_graph(
    most_profit_clients, 'прибыль', 50, 
   'Распределение прибыли среди покупателей магазина, со снижением покупательской активности'
)
# Out:
# count    353.000000
# mean       4.019065
# std        1.001917
# min        1.060000
# 25%        3.360000
# 50%        4.080000
# 75%        4.650000
# max        7.430000
# Name: прибыль, dtype: float64

# %% [markdown]
# Посмотрим на распределение прибыли в датафрейме с полным набором данных:

# %%
num_stat_and_graph(
    profit, 'прибыль', 50, 
   'Распределение прибыли среди покупателей магазина, со снижением покупательской активности'
)
# Out:
# count    1297.000000
# mean        3.997610
# std         1.010813
# min         0.860000
# 25%         3.300000
# 50%         4.040000
# 75%         4.670000
# max         7.430000
# Name: прибыль, dtype: float64

# %% [markdown]
# По графикам выше заметно, что отфильтрованный датасет, вцелом, не сильно отличается от общего набора данных по параметру 'прибыль'. что говорит о том, что затраты на маркетинговые мероприятия по удержанию данных клиентов обоснованы, так как данные клиенты приносят компании среднестатистическую прибыль

# %% [markdown]
# Полученный список из 353 человек, может быть передан маркетолагам с целью проведения акционных рассылок по данному списку (т.к. акционные покупки являются важным признаком, желательно, чтобы ссылки содержащиеся в данном письме, побуждали покупателя к переходу на сайт (таким образом пытаясь увеличить параметры 'страниц за визит' и 'просмотр категорий за визит')

# %% [markdown]
# **Вывод:** С целью повышения покупательской активности клиентов, получивших прогнох о снижении покупательской способности в ближайшее время, был сформирован датафрейм с id покупателей, получивших такой прогноз, к этому датафрейму были добавлены сведения о прибыли от данных клиентов, за последнии 3 месяца и категории любимых товаров, которые покупают данные пользователи. После чего было определено топ-3 категорий товаров среди отфильтрованных пользователей. В итоговый датафрейм отобрали пользователей популярной категорией товаров из топ-3 и отфильтровали его по убыванию прибыли.
#
# Полученный список из 353 человек, может быть передан маркетолагам с целью проведения акционных рассылок по данному списку (т.к. акционные покупки являются важным признаком, желательно, чтобы ссылки содержащиеся в данном письме, побуждали покупателя к переходу на сайт (таким образом пытаясь увеличить параметры 'страниц за визит' и 'просмотр категорий за визит')
# По результатам распределения прибыли отфильтрованного и общего датасета, утановлено,  что отфильтрованный датасет, вцелом, не сильно отличается от общего набора данных по параметру 'прибыль', что говорит о том, что затраты на маркетинговые мероприятия по удержанию данных клиентов обоснованы, так как данные клиенты приносят компании среднестатистическую прибыль.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Целью данного исследование является изучение отчета интернет-магазина «В один клик».  Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. выход из данной ситуации — удерживать активность постоянных клиентов. Сделать это планируется с помощью персонализированных предложений.
#
# Необходимо разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность, но для начала необходимо определить клиентов, покупательская способность которых будет снижена в ближайщее время.
#
# Предоставленные к исследованию датасеты проверены на наличие пропусков, корректность типа данных, явных и неявных дубликатов (по номеру id). Пропуски и дубликаты в исследуемых датафреймах не выявлены, типы данных значений корректны. Дополнительная обработка данных не требуется.
#
# Из всех датасетов удалены id пользователей, имеющих выручку равную нулю, хотя бы в одном, из трех последних месяцев. По результатам проведенного исследовательского анализа изучаемых датасетов, можно прийти к выводу, что вцелом представленные данные не содержат аномальных значений. Столбец 'выручка' датасета money имеет выброс значением 106862, однако данное значение реально в рамках имеющегося набора данных и поэтому датафрейм money оставлен без изменений. Распределение значений вцелом имеет вид нормального с более или менее выраженными смещениями относительно центра значений.
#
# Выполнено объединение датасетов market, money и time в один датафрейм. Значения выручки и времени из датасетов money и time,  пропиcаны в отдельном столбце для каждого периода.
#
# Определены коэффициенты корреляции Спирмена, построены матрица и тепловыая карта со значениями коэффициентов корреляции. Сильнокоррелирующие положительно параметры не выявлены, имеются параметры имеющие сильную отрицательную корреляцию - 'минут_предыдущий_месяц' и 'минут_текущий_месяц'.
# <a id='section_id6'></a>
# Для поиска лучшей модели и метрики для поиска клиентов покупательская активность которых будет снижаться в ближайшее время, построен и просчитан пайплайн, со следующими исходными параметрами:
#
# - в качестве кодировщиков использовались OheHotEncoder и OrdinalEncoder.
# - в качестве скейлеров использовались StandaradScaler, MinMaxScaler, RobustScaler.
# - в качестве моделей МО применялись KNeighborsClassifier() (перебирали гиперпараметр 'n_neighbors', DecisionTreeClassifier() (перебирали гиперпараметры 'max_depth', 'min_samples_split', 'min_samples_leaf' , LogisticRegression(перебирали гиперпараметр 'С') и SVC(перебирали гиперпараметр 'degree').
# - в качестве метрики, с помощью которой будет оценивалось качество модели, использовали ROC-AUC.
#
# По итогу лучшие показатели показала модель со следующими параметрами:
# - кодировщик OheHotEncoder;
# - скейлер StandaradScaler;
# - модель DecisionTreeClassifier() с гиперпараметрами 'max_depth' = 18, 'min_samples_split' = 8.
#
# Лучшая метрика ROC-AUC полученная на кросс-валидационной выборке равно 0.9874060771432089
#
# Лучшая метрика ROC-AUC полученная на тестовой выборке равно 0.9961815962561071
#
# Исходя из полученных значений разброса и смещенияможно сказать о том, что модель получила достаточно сведений для принятия решений, при этом не переобучившись.
#
# По результатам анализа графиков SHAP, можно прийти к следующим выводам:
# Возьмем за границу, разделяющую важные признаки от неважных - среднее значение Шепли, равные 0.02. Тогда получим, что:
#
# - менее всего на прогноз целевого признака влияют следующие входные параметры: 'выручка', 'тип_сервиса', 'разрешить_сообщать', 'маркет_актив_тек_месяц';
# - более всего на прогноз целевого признака влияют следующие входные параметры: 'страниц за визит', 'акционные_покупки', 'маркет_актив_6_мес', 'просмотр категорий за визит', 'минут', 'неоплаченные_продукты_штук_квартал', 'длительность', 'ошибка_сервиса'.
# На основании описанного выше, для увеличения покупательской активности вцелом можно рекомендовать отделу маркетинга делать рассылки, которые приводят к переходу покупателей на страницы магазина, т.к. 'страниц за визит' это самый влиятельный входной признак (также в числе влиятельный признаков 'просмотр категорий за визит', 'минут', 'длительность' - величина данных параметров зависит от количетсва переходов и степенью заинтересованности информацией на страницах сайта/приложения. Также можно рекомендовать предложение клиентам акционных покупок и увеличение маркетинговой активности целом.
#
# С целью повышения покупательской активности клиентов, получивших прогнох о снижении покупательской способности в ближайшее время, был сформирован датафрейм с id покупателей, получивших такой прогноз, к этому датафрейму были добавлены сведения о прибыли от данных клиентов, за последнии 3 месяца и категории любимых товаров, которые покупают данные пользователи. После чего было определено топ-3 категорий товаров среди отфильтрованных пользователей. В итоговый датафрейм отобрали пользователей популярной категорией товаров из топ-3 и отфильтровали его по убыванию прибыли.
#
# Полученный список из 353 человек, может быть передан маркетолагам с целью проведения акционных рассылок по данному списку (т.к. акционные покупки являются важным признаком, желательно, чтобы ссылки содержащиеся в данном письме, побуждали покупателя к переходу на сайт (таким образом пытаясь увеличить параметры 'страниц за визит' и 'просмотр категорий за визит')
# По результатам распределения прибыли отфильтрованного и общего датасета, утановлено,  что отфильтрованный датасет, вцелом, не сильно отличается от общего набора данных по параметру 'прибыль', что говорит о том, что затраты на маркетинговые мероприятия по удержанию данных клиентов обоснованы, так как данные клиенты приносят компании среднестатистическую прибыль.

# %% [markdown]
# Ссылка на репозиторий GitHub - https://github.com/Ortert/supervised_learning
